-- %% [markdown]
-- # **Titulo 1**
-- ## Titulo 2
-- ### Titulo 3
-- - First item
-- - Second item
-- - Third item
-- `Hola`
-- ---
-- | Syntax | Description |
-- | ----------- | ----------- |
-- | Header | Title |
-- | Paragraph | Text |

-- %% [markdown]
-- ```
-- {
--   "firstName": "John",
--   "lastName": "Smith",
--   "age": 25
-- }
-- ```

-- %%
%python
a=5
b=[1,2]

print(a)
print(b*3)
