# %% [markdown]
# ### <image src="https://storagepocdemos.blob.core.windows.net/public/images/databricks_banner.png?sp=r&st=2025-09-07T16:20:01Z&se=2027-01-01T04:59:59Z&spr=https&sv=2024-11-04&sr=b&sig=93gWaOconS54rPMBkuUQ5hq9ji6GVlLPofBBZeI7yYI%3D" width="100%" alt="handytec">

# %% [markdown]
# ### Carga de Datos
# #### CSV dese URL

# %%
# %py
import pandas as pd
CSV_URL="https://storagepocdemos.blob.core.windows.net/public/documents/insurance_sample.csv?sp=r&st=2025-09-08T20:22:14Z&se=2027-01-01T04:59:59Z&spr=https&sv=2024-11-04&sr=b&sig=uUEG5%2FuqAjs1VVs4ayO7O8%2F2hDViE%2BKGqbNJZlA2Kr0%3D"

df_pandas=pd.read_csv(CSV_URL,sep=',', header='infer')
df = spark.createDataFrame(df_pandas)
display(df_pandas)
# Out:
# Databricks data profile. Run in Databricks to view.

# %%
path="/Volumes/dbw_edwh_training/db_bronze/input_files/Ejemplo01.csv"
df = spark.read.csv(path = path, header=True, encoding='UTF-8',inferSchema=True, sep=',', multiLine=True)
display(df)
# Out:
# Databricks data profile. Run in Databricks to view.
