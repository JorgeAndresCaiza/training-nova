-- %% [markdown]
-- # Titulo 1
-- ## Titulo 2
-- ### Titulo 3

-- %% [markdown]
-- | Syntax | Description |
-- | ----------- | ----------- |
-- | 15-09-2025 | Tabla Markdwon |
-- | Paragraph | Text |

-- %% [markdown]
-- - [x] Write the press release
-- - [ ] Update the website
-- - [ ] Contact the media

-- %%
%python
a=5
b=3
c=[1,2]
print(a+b)
print(c*3)

-- %%
SELECT 
  workspace_id,
  job_id,
  COUNT(*) AS run_count
FROM 
  information_schema.job_history
GROUP BY 
  workspace_id,
  job_id
ORDER BY 
  run_count DESC
LIMIT 1

-- %%
select 1 as D, now() horaUTC,from_utc_timestamp(now(),'America/Lima') Hora_Actual
