# %% [markdown]
# # H1
# ## H2
# ### H3

# %% [markdown]
# | Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
# | Paragraph | Text |

# %% [markdown]
# - [x] Write the press release
# - [ ] Update the website
# - [ ] Contact the media
